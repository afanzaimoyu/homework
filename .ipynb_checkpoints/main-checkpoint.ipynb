# %% [markdown]
# ###### 了解数据
# 导入模块

# %%
import pandas as pd

# %% [markdown]
# 加载数据

# %%
df1 = pd.read_csv('流行电影评分预测1.csv')
df2 = pd.read_csv('流行电影评分预测2.csv')

# %% [markdown]
# 删除冗余特征

# %%
df1.drop(columns=['Unnamed: 0'], inplace=True)
df2.drop(columns=['Unnamed: 0'], inplace=True)
df2.columns
# Out:
# Index(['影片', '年份', '时长', '评分', '票房'], dtype='object')

# %% [markdown]
# 拼接数据

# %%
df = pd.merge(df1, df2, on='影片', how='inner')

# %% [markdown]
# 查看数据样式

# %%
df.head()
# Out:
#                                  影片                       类型
# 0                 X-Men: Apocalypse  Action,Adventure,Sci-Fi  \
# 1                          Deadpool  Action,Adventure,Comedy
# 2  Resident Evil: The Final Chapter     Action,Horror,Sci-Fi
# 3        Captain America: Civil War  Action,Adventure,Sci-Fi
# 4                      Interstellar   Adventure,Drama,Sci-Fi
#
#                                                   简介                  导演
# 0  After the re-emergence of the world's first mu...        Bryan Singer  \
# 1  A fast-talking mercenary with a morbid sense o...          Tim Miller
# 2  Alice returns to where the nightmare began: Th...  Paul W.S. Anderson
# 3  Political interference in the Avengers' activi...       Anthony Russo
# 4  A team of explorers travel through a wormhole ...   Christopher Nolan
#
#                                                   主演    年份      时长   评分
# 0  James McAvoy, Michael Fassbender, Jennifer Law...  2016  144min  7.1  \
# 1  Ryan Reynolds, Morena Baccarin, T.J. Miller, E...  2016  108min  8.0
# 2  Milla Jovovich, Iain Glen, Ali Larter, Shawn R...  2016  107min  5.6
# 3  Chris Evans, Robert Downey Jr.,Scarlett Johans...  2016  147min  7.9
# 4  Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014  169min  8.6
#
#        票房
# 0  155.33
# 1  363.02
# 2   26.84
# 3  408.08
# 4  187.99

# %% [markdown]
# 查看数据形状，样本数量

# %%
df.shape
# Out:
# (1066, 9)

# %%
len(df)
# Out:
# 1066

# %% [markdown]
# 查看缺失值大概情况

# %%
df.isnull().sum()
# Out:
# 影片      0
# 类型      0
# 简介      0
# 导演      0
# 主演      0
# 年份      7
# 时长      0
# 评分      7
# 票房    146
# dtype: int64

# %% [markdown]
# 查看数据统计特征

# %%
df.describe(include='all')
# Out:
#                 影片     类型                                                 简介
# count         1066   1066                                               1066  \
# unique         967    206                                                968
# top     Nine Lives  Drama  A stuffy businessman finds himself trapped ins...
# freq             4     50                                                  4
# mean           NaN    NaN                                                NaN
# std            NaN    NaN                                                NaN
# min            NaN    NaN                                                NaN
# 25%            NaN    NaN                                                NaN
# 50%            NaN    NaN                                                NaN
# 75%            NaN    NaN                                                NaN
# max            NaN    NaN                                                NaN
#
#                         导演                                                 主演
# count                 1066                                               1066  \
# unique                 626                                                964
# top     Paul W.S. Anderson  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# freq                     9                                                  4
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN
#
#           年份     时长    评分          票房
# count   1059   1066  1059  920.000000
# unique    15     96    56         NaN
# top     2016  92min   7.1         NaN
# freq     280     33    54         NaN
# mean     NaN    NaN   NaN   77.753402
# std      NaN    NaN   NaN   98.324979
# min      NaN    NaN   NaN    0.000000
# 25%      NaN    NaN   NaN   13.765000
# 50%      NaN    NaN   NaN   45.800000
# 75%      NaN    NaN   NaN  100.630000
# max      NaN    NaN   NaN  936.630000

# %% [markdown]
# ###### 数据处理

# %% [markdown]
# 重复值

# %%
df.duplicated().sum()
# Out:
# 93

# %%
duplicate_rows = df.duplicated()
duplicate_data = df[duplicate_rows]
duplicate_data
# Out:
#                           影片                        类型
# 939                  Wrecker    Action,Horror,Thriller  \
# 940                  Wrecker    Action,Horror,Thriller
# 941                  Wrecker    Action,Horror,Thriller
# 943          The Lone Ranger  Action,Adventure,Western
# 944          The Lone Ranger  Action,Adventure,Western
# ...                      ...                       ...
# 1057  Step Up 2: The Streets       Drama,Music,Romance
# 1060            Search Party          Adventure,Comedy
# 1061            Search Party          Adventure,Comedy
# 1064              Nine Lives     Comedy,Family,Fantasy
# 1065              Nine Lives     Comedy,Family,Fantasy
#
#                                                      简介                导演
# 939   Best friends Emily and Lesley go on a road tri...    Micheal Bafaro  \
# 940   Best friends Emily and Lesley go on a road tri...    Micheal Bafaro
# 941   Best friends Emily and Lesley go on a road tri...    Micheal Bafaro
# 943   Native American warrior Tonto recounts the unt...    Gore Verbinski
# 944   Native American warrior Tonto recounts the unt...    Gore Verbinski
# ...                                                 ...               ...
# 1057  Romantic sparks occur between two dance studen...        Jon M. Chu
# 1060  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1061  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1064  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
# 1065  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                      主演    年份       时长   评分
# 939   Anna Hutchison, Andrea Whitburn, Jennifer Koen...  2015    83min  3.5  \
# 940   Anna Hutchison, Andrea Whitburn, Jennifer Koen...  2015    83min  3.5
# 941   Anna Hutchison, Andrea Whitburn, Jennifer Koen...  2015    83min  3.5
# 943   Johnny Depp, Armie Hammer, William Fichtner,To...  2013   150min  6.5
# 944   Johnny Depp, Armie Hammer, William Fichtner,To...  2013   150min  6.5
# ...                                                 ...   ...      ...  ...
# 1057  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008  1h38min  6.2
# 1060  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014    93min  5.6
# 1061  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014  1h23min  5.6
# 1064  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016    87min  5.3
# 1065  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016  1h27min  5.3
#
#          票房
# 939     NaN
# 940     NaN
# 941     NaN
# 943   89.29
# 944   89.29
# ...     ...
# 1057  58.01
# 1060    NaN
# 1061    NaN
# 1064  19.64
# 1065  19.64
#
# [93 rows x 9 columns]

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 缺失值处理

# %%
df.isnull().sum()
# Out:
# 影片      0
# 类型      0
# 简介      0
# 导演      0
# 主演      0
# 年份      7
# 时长      0
# 评分      7
# 票房    126
# dtype: int64

# %%
df[df['年份'].isnull()]
# Out:
#                                      影片                      类型
# 621                              Solace     Crime,Drama,Mystery  \
# 623  Popstar: Never Stop Never Stopping            Comedy,Music
# 689                           Neighbors                  Comedy
# 763                 Ma vie de Courgette  Animation,Comedy,Drama
# 765                 No Strings Attached          Comedy,Romance
# 785                          Inside Man     Crime,Drama,Mystery
# 852                       Transcendence   Drama,Mystery,Romance
#
#                                                     简介                导演
# 621  A psychic works with the FBI in order to hunt ...     Afonso Poyart  \
# 623  When it becomes clear that his solo album is a...    Akiva Schaffer
# 689  After they are forced to live next to a frater...  Nicholas Stoller
# 763  After losing his mother, a young boy is sent t...     Claude Barras
# 765  A guy and girl try to keep their relationship ...      Ivan Reitman
# 785  A police detective, a bank robber, and a high-...         Spike Lee
# 852  A scientist's drive for artificial intelligenc...     Wally Pfister
#
#                                                     主演   年份      时长   评分
# 621  Anthony Hopkins, Jeffrey Dean Morgan, Abbie Co...  NaN  101min  NaN  \
# 623  Andy Samberg, Jorma Taccone,Akiva Schaffer, Sa...  NaN   87min  NaN
# 689     Seth Rogen, Rose Byrne, Zac Efron, Lisa Kudrow  NaN   97min  NaN
# 763  Gaspard Schlatter, Sixtine Murat, Paulin Jacco...  NaN   66min  NaN
# 765  Natalie Portman, Ashton Kutcher, Kevin Kline, ...  NaN  108min  NaN
# 785  Denzel Washington, Clive Owen, Jodie Foster,Ch...  NaN  129min  NaN
# 852  Johnny Depp, Rebecca Hall, Morgan Freeman, Cil...  NaN  119min  NaN
#
#          票房
# 621     NaN
# 623    9.39
# 689  150.06
# 763    0.29
# 765   70.63
# 785   88.50
# 852   23.01

# %%
# 清洗年份列，将特殊字符替换为NaN或空字符串
df['年份'] = df['年份'].str.replace(r'\D', '', regex=True).replace('', pd.NA)

# 清洗评分列，将特殊字符替换为NaN或空字符串
df['评分'] = df['评分'].str.replace(r'[^0-9.]', '', regex=True).replace('', pd.NA)  # ^出现在[]内 表示取反

# 将年份列转换为整数类型
df['年份'] = df['年份'].astype('Int32')

# 填充年份、评分和票房列的缺失值
df['年份'].fillna(df['年份'].median(), inplace=True)
df['评分'].fillna(df['评分'].median(), inplace=True)
df['票房'].fillna(df['票房'].mode()[0], inplace=True)

# 将评分列转换为整数类型
df['评分'] = df['评分'].astype('float')

# %% [markdown]
# 将“时长”统一格式

# %%
# 检查时长列是否都是数字+min结尾
is_valid_duration = df['时长'].str.match(r'^\d+min$')

# 打印不符合条件的行
for index in  df[~is_valid_duration].index:
    # 提取时长中的小时和分钟信息
    duration_hours = int(df.loc[index, '时长'].split('h')[0])
    duration_minutes = int(df.loc[index, '时长'].split('h')[1].replace('min', ''))

    # 将小时和分钟转化为分钟数
    total_duration_minutes = str(duration_hours * 60 + duration_minutes) + 'min'

    # 更新时长列为转化后的分钟数
    df.loc[index, '时长'] = total_duration_minutes
df[~is_valid_duration]
# Out:
#                           影片                     类型
# 1055  Step Up 2: The Streets    Drama,Music,Romance  \
# 1059            Search Party       Adventure,Comedy
# 1063              Nine Lives  Comedy,Family,Fantasy
#
#                                                      简介                导演
# 1055  Romantic sparks occur between two dance studen...        Jon M. Chu  \
# 1059  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1063  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                      主演    年份     时长   评分
# 1055  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008  98min  6.2  \
# 1059  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014  83min  5.6
# 1063  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016  87min  5.3
#
#          票房
# 1055  58.01
# 1059   0.03
# 1063  19.64

# %%
df.isnull().sum()
# Out:
# 影片    0
# 类型    0
# 简介    0
# 导演    0
# 主演    0
# 年份    0
# 时长    0
# 评分    0
# 票房    0
# dtype: int64

# %%
df.dtypes
# Out:
# 影片     object
# 类型     object
# 简介     object
# 导演     object
# 主演     object
# 年份      Int32
# 时长     object
# 评分    float64
# 票房    float64
# dtype: object

# %%
df
# Out:
#                                     影片                       类型
# 0                    X-Men: Apocalypse  Action,Adventure,Sci-Fi  \
# 1                             Deadpool  Action,Adventure,Comedy
# 2     Resident Evil: The Final Chapter     Action,Horror,Sci-Fi
# 3           Captain America: Civil War  Action,Adventure,Sci-Fi
# 4                         Interstellar   Adventure,Drama,Sci-Fi
# ...                                ...                      ...
# 1055            Step Up 2: The Streets      Drama,Music,Romance
# 1058                      Search Party         Adventure,Comedy
# 1059                      Search Party         Adventure,Comedy
# 1062                        Nine Lives    Comedy,Family,Fantasy
# 1063                        Nine Lives    Comedy,Family,Fantasy
#
#                                                      简介                  导演
# 0     After the re-emergence of the world's first mu...        Bryan Singer  \
# 1     A fast-talking mercenary with a morbid sense o...          Tim Miller
# 2     Alice returns to where the nightmare began: Th...  Paul W.S. Anderson
# 3     Political interference in the Avengers' activi...       Anthony Russo
# 4     A team of explorers travel through a wormhole ...   Christopher Nolan
# ...                                                 ...                 ...
# 1055  Romantic sparks occur between two dance studen...          Jon M. Chu
# 1058  A pair of friends embark on a mission to reuni...      Scot Armstrong
# 1059  A pair of friends embark on a mission to reuni...      Scot Armstrong
# 1062  A stuffy businessman finds himself trapped ins...    Barry Sonnenfeld
# 1063  A stuffy businessman finds himself trapped ins...    Barry Sonnenfeld
#
#                                                      主演    年份      时长   评分
# 0     James McAvoy, Michael Fassbender, Jennifer Law...  2016  144min  7.1  \
# 1     Ryan Reynolds, Morena Baccarin, T.J. Miller, E...  2016  108min  8.0
# 2     Milla Jovovich, Iain Glen, Ali Larter, Shawn R...  2016  107min  5.6
# 3     Chris Evans, Robert Downey Jr.,Scarlett Johans...  2016  147min  7.9
# 4     Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014  169min  8.6
# ...                                                 ...   ...     ...  ...
# 1055  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008   98min  6.2
# 1058  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014   93min  5.6
# 1059  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014   83min  5.6
# 1062  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016   87min  5.3
# 1063  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016   87min  5.3
#
#           票房
# 0     155.33
# 1     363.02
# 2      26.84
# 3     408.08
# 4     187.99
# ...      ...
# 1055   58.01
# 1058    0.03
# 1059    0.03
# 1062   19.64
# 1063   19.64
#
# [973 rows x 9 columns]
